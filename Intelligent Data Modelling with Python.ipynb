# %% [markdown]
# <a href="https://colab.research.google.com/github/praba-engineer/Python-Hands-on-Practice/blob/main/Intelligent%20Data%20Modelling%20with%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Write your code here

name = "Prabakaran"
print(name.upper())
# Out:
# PRABAKARAN

# %%
text = "Artificial Intelligence"
print(len(text))
print(text.lower())
# Out:
# 23
# artificial intelligence

# %%
numbers = [10, 20, 30, 40, 50]
print(max(numbers))
# Out:
# 50

# %%
courses = ["Python", "SQL"]
courses.append("Excel")
print(courses)
# Out:
# ['Python', 'SQL', 'Excel']

# %%
cities = ("Chennai", "Bangalore", "Hyderabad", "Mumbai")
print(cities[1])
# Out:
# Bangalore

# %%
numbers = (10, 20, 30, 40, 50)
print(len(numbers))
# Out:
# 5

# %%
student = {
      "Name": "Prabakaran",
          "Score": 95
          }

print(student["Score"])
# Out:
# 95

# %%
student = {
    "Name": "Prabakaran",
    "Score": 95
}

student["Department"] = "IT"
print(student)
# Out:
# {'Name': 'Prabakaran', 'Score': 95, 'Department': 'IT'}

# %%
employee = {
    "Name": "Prabakaran",
    "Skills": ["Python", "SQL", "Azure Data Factory"],
    "Location": "Chennai"
}

print(employee.values())
# Out:
# dict_values(['Prabakaran', ['Python', 'SQL', 'Azure Data Factory'], 'Chennai'])
